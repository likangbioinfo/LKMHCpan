# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_ind
import random

# %% [markdown]
# 在TESTLA数据中，每个样本中LKMHCpan2预测得分的排名能力

# %%
df=pd.read_csv("/life/Project/liqing/02.Work/01.LNEA.toolkit/01.MHCImodel/24.model.Roberta.20230606/04.paper/02.HLA_generalizability/04.HLA_Anchorpos/Table_each_patient_PRAUC.xls",sep="\t")

axis = df.plot.barh(rot=0,x='patient',figsize=(4, 4),edgecolor='black')
# 关闭次要网格线
plt.grid(which='minor', linestyle='')
plt.grid(which='minor', linestyle='')

# 显示图形
#plt.title('Na')
plt.ylabel("Patient")
plt.xlabel("AUPRC")
plt.savefig("Table_plot_boxplot_AUPRC_eachpatient.svg")
plt.show()
